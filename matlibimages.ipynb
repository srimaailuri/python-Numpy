# %%
from urllib.request import urlretrieve

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#before an image can be displayed,it has to be read into the memory using the PIL module
from PIL import Image

# %%
#copy paste the url and name the file name where it has to be stored 
urlretrieve('https://cdn3.geckoandfly.com/wp-content/uploads/2014/03/life-quotes-inspirational-inspiring-motivational39.jpg','lifequote.jpg')
# Out:
# ('lifequote.jpg', <http.client.HTTPMessage at 0x19f7b517a30>)

# %%
img=Image.open('lifequote.jpg')

# %%
# to find the dimensions of the array
img_array=np.array(img)
img_array.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img);

# %%
plt.title(' life quote ')
plt.imshow(img);

# %%
#this command is used to extract the subpart of the image
plt.imshow(img_array[225:425,305:505]);

# %% [markdown]
# ### drawing multiple charts or graphs in a grid

# %%
plt.subplots(2,3)
# Out:
# (<Figure size 432x288 with 6 Axes>,
#  array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#         [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object))

# %%
#tight_layout(pad=2) is used for padding
plt.subplots(2,3)
plt.tight_layout(pad=2)

# %%
fig,axes=plt.subplots(2,3,figsize=(16,8))

# %%
#plotting inside subplots
#both x and y should have the same size
#you can add figsize inorder to increase the size of the subplots
fig,axes=plt.subplots(2,3,figsize=(12,9))
years=[2010,2011,2012,2013,2014,2015]
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908 ]
axes[0,0].plot(years,apples,'s-b')
axes[0,0].plot(years,oranges,'o--r')
axes[0,0].set_title("crop yeild")
axes[0,0].set_xlabel("years")
axes[0,0].set_ylabel("yeild(tons per hectare)")
axes[0,0].legend(['apples','oranges'])
sns.set_style("darkgrid")
plt.tight_layout(pad=2)

flowers_df=sns.load_dataset("iris")
axes[0,1].set_title('sepal length vs width')
sns.scatterplot(x=flowers_df.sepal_length,y=flowers_df.sepal_width,hue=flowers_df.species,s=100,ax=axes[0,1]);

# Use the axes for plotting
setosa_df=flowers_df[flowers_df.species=='setosa']
versicolor_df=flowers_df[flowers_df.species=='versicolor']
virginica_df=flowers_df[flowers_df.species=='virginica']
axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width], 
         bins=np.arange(2, 5, 0.25), 
         stacked=True);

axes[0,2].legend(['Setosa', 'Versicolor', 'Virginica']);

tips_df=sns.load_dataset('tips')
axes[1,0].set_title('Restaurant bills')
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df, ax=axes[1,0]);

# Pass the axes into seaborn
flights_df=sns.load_dataset('flights').pivot("month","year","passengers")
axes[1,1].set_title('Flight traffic')
sns.heatmap(flights_df, cmap='Blues', ax=axes[1,1]);

# Plot an image using the axes
axes[1,2].set_title('Data Science Meme')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])
# Out:
# []
